# %% [markdown]
# **1. Classes & Instances**

# %%
class Employee:
  pass

emp_1 = Employee()
emp_2 = Employee()

print(emp_1)
print(emp_2)

emp_1.first = 'jan'
emp_1.last = 'michel'
emp_1.email = 'jan.michel@company.com'
emp_1.pay = 79000

emp_2.first = 'harry'
emp_2.last = 'cob'
emp_2.email = 'harry.cob@company.com'
emp_2.pay = 99000

print(emp_1.email)
print(emp_2.email)
# Out:
# ...
# jan.michel@company.com
# harry.cob@company.com

# %%
class Employee:
      def __init__(self, first, last, pay):
          self.first = first
          self.last = last
          self.pay = pay
          self.email = first + '.' + last + '@company.com'

emp_1 = Employee('jan', 'michel', 79000)
emp_2 = Employee('harry', 'cob', 99000)

print(emp_1.email)
print(emp_2.email)
print('{} {}'.format(emp_1.first, emp_1.last))
# Out:
# jan.michel@company.com
# harry.cob@company.com
# jan michel

# %%
class Employee:
      def __init__(self, first, last, pay):
          self.first = first
          self.last = last
          self.pay = pay
          self.email = first + '.' + last + '@company.com'
      def fullname(self):
          return ('{} {}'.format(self.first, self.last))

emp_1 = Employee('jan', 'michel', 79000)
emp_2 = Employee('harry', 'cob', 99000)

print(emp_1.fullname())
print(emp_2.fullname())
# Out:
# jan michel
# harry cob

# %% [markdown]
# **2. Class Variables**

# %%
class Employee:
      def __init__(self, first, last, pay):
          self.first = first
          self.last = last
          self.pay = pay
          self.email = first + '.' + last + '@company.com'

      def fullname(self):
          return ('{} {}'.format(self.first, self.last))

      def apply_raise(self):
        self.pay = int(self.pay * 1.04)


emp_1 = Employee('jan', 'michel', 79000)
emp_2 = Employee('harry', 'cob', 99000)

print(emp_1.pay)
emp_1.apply_raise()
print(emp_1.pay)
# Out:
# 79000
# 82160

# %%
class Employee:

      raise_amount = 1.04

      def __init__(self, first, last, pay):
          self.first = first
          self.last = last
          self.pay = pay
          self.email = first + '.' + last + '@company.com'

      def fullname(self):
          return ('{} {}'.format(self.first, self.last))

      def apply_raise(self):
        self.pay = int(self.pay * Employee.raise_amount)


emp_1 = Employee('jan', 'michel', 79000)
emp_2 = Employee('harry', 'cob', 99000)

print(Employee.raise_amount)
print(emp_1.raise_amount)
print(emp_2.raise_amount)
# Out:
# 1.04
# 1.04
# 1.04

# %%
class Employee:

      raise_amount = 1.04

      def __init__(self, first, last, pay):
          self.first = first
          self.last = last
          self.pay = pay
          self.email = first + '.' + last + '@company.com'

      def fullname(self):
          return ('{} {}'.format(self.first, self.last))

      def apply_raise(self):
        self.pay = int(self.pay * Employee.raise_amount)


emp_1 = Employee('jan', 'michel', 79000)
emp_2 = Employee('harry', 'cob', 99000)

emp_1.raise_amount =1.05

print(Employee.raise_amount)
print(emp_1.raise_amount)
print(emp_2.raise_amount)
# Out:
# 1.04
# 1.05
# 1.04

# %%
class Employee:

      raise_amount = 1.04

      def __init__(self, first, last, pay):
          self.first = first
          self.last = last
          self.pay = pay
          self.email = first + '.' + last + '@company.com'

      def fullname(self):
          return ('{} {}'.format(self.first, self.last))

      def apply_raise(self):
        self.pay = int(self.pay * Employee.raise_amount)


emp_1 = Employee('jan', 'michel', 79000)
emp_2 = Employee('harry', 'cob', 99000)

emp_1.raise_amount =1.05

print(emp_1.__dict__)
print(Employee.__dict__)


print(Employee.raise_amount)
print(emp_1.raise_amount)
print(emp_2.raise_amount)
# Out:
# {'first': 'jan', 'last': 'michel', 'pay': 79000, 'email': 'jan.michel@company.com', 'raise_amount': 1.05}
# {'__module__': '__main__', 'raise_amount': 1.04, '__init__': <function Employee.__init__ at 0x7be6b5d5a3e0>, 'fullname': <function Employee.fullname at 0x7be69d82ab60>, 'apply_raise': <function Employee.apply_raise at 0x7be69d82aac0>, '__dict__': <attribute '__dict__' of 'Employee' objects>, '__weakref__': <attribute '__weakref__' of 'Employee' objects>, '__doc__': None}
# 1.04
# 1.05
# 1.04

# %%
class Employee:

      num_of_emps = 0
      raise_amount = 1.04

      def __init__(self, first, last, pay):
          self.first = first
          self.last = last
          self.pay = pay
          self.email = first + '.' + last + '@company.com'

          Employee.num_of_emps += 1

      def fullname(self):
          return ('{} {}'.format(self.first, self.last))

      def apply_raise(self):
        self.pay = int(self.pay * Employee.raise_amount)

print(Employee.num_of_emps)

emp_1 = Employee('jan', 'michel', 79000)
emp_2 = Employee('harry', 'cob', 99000)

print(Employee.num_of_emps)
# Out:
# 0
# 2

# %% [markdown]
# **3. Classmethods & Staticsmethods**

# %%
class Employee:

      num_of_emps = 0
      raise_amt = 1.04

      def __init__(self, first, last, pay):
          self.first = first
          self.last = last
          self.pay = pay
          self.email = first + '.' + last + '@company.com'

          Employee.num_of_emps += 1

      def fullname(self):
          return ('{} {}'.format(self.first, self.last))

      def apply_raise(self):
        self.pay = int(self.pay * self.raise_amount)

      @classmethod
      def set_raise_amt(cls, amount):
          cls.raise_amt = amount

emp_1 = Employee('jan', 'michel', 79000)
emp_2 = Employee('harry', 'cob', 99000)

Employee.set_raise_amt(1.05)

print(Employee.raise_amt)
print(emp_1.raise_amt)
print(emp_2.raise_amt)
# Out:
# 1.05
# 1.05
# 1.05

# %%
class Employee:

      num_of_emps = 0
      raise_amt = 1.04

      def __init__(self, first, last, pay):
          self.first = first
          self.last = last
          self.pay = pay
          self.email = first + '.' + last + '@company.com'

          Employee.num_of_emps += 1

      def fullname(self):
          return ('{} {}'.format(self.first, self.last))

      def apply_raise(self):
        self.pay = int(self.pay * self.raise_amount)

      @classmethod
      def set_raise_amt(cls, amount):
          cls.raise_amt = amount

emp_1 = Employee('jan', 'michel', 79000)
emp_2 = Employee('harry', 'cob', 99000)

emp_str_1 = 'John-Doe-70000'
emp_str_2 = 'steve-smith-30000'
emp_str_3 = 'Jane-Doe-90000'

first, last, pay = emp_str_1.split(('-'))

new_emp_1 = Employee(first, last, pay)

print(new_emp_1.email)
print(new_emp_1.pay)
# Out:
# John.Doe@company.com
# 70000

# %% [markdown]
# Alternative of aove method

# %%
class Employee:

      num_of_emps = 0
      raise_amt = 1.04

      def __init__(self, first, last, pay):
          self.first = first
          self.last = last
          self.pay = pay
          self.email = first + '.' + last + '@company.com'

          Employee.num_of_emps += 1

      def fullname(self):
          return ('{} {}'.format(self.first, self.last))

      def apply_raise(self):
        self.pay = int(self.pay * self.raise_amount)

      @classmethod
      def set_raise_amt(cls, amount):
          cls.raise_amt = amount

      @classmethod
      def from_string(cls, emp_str):
          first, last, pay = emp_str_1.split(('-'))
          return cls(first, last, pay)

emp_1 = Employee('jan', 'michel', 79000)
emp_2 = Employee('harry', 'cob', 99000)

emp_str_1 = 'John-Doe-70000'
emp_str_2 = 'steve-smith-30000'
emp_str_3 = 'Jane-Doe-90000'

new_emp_1 = Employee.from_string(emp_str_1)

print(new_emp_1.email)
print(new_emp_1.pay)
# Out:
# John.Doe@company.com
# 70000

# %% [markdown]
# **Additional constructors**

# %%
@classmethod
def fromtimestamp(cls, t):
  "construct a date from a POSIX timestamp (like time.time())."
  y, m, d, hh, mm, ss, weekday, jday, dst = _time.localtime(t)
  return cls(y,m,d)

  @classmethod
  def today(cls):
    "construct a date from time.time()."
    t = _time.time()
    return cls.fromtimestamp(t)

  @classmethod
  def fromordinal(cls, n):
    """construct a date from a proleptic gregorian ordinal.

    January 1 of year 1 is day 1. only the year, month and day are
    non-zero in the result.
    """

# %%
class Employee:

      num_of_emps = 0
      raise_amt = 1.04

      def __init__(self, first, last, pay):
          self.first = first
          self.last = last
          self.pay = pay
          self.email = first + '.' + last + '@company.com'

          Employee.num_of_emps += 1

      def fullname(self):
          return ('{} {}'.format(self.first, self.last))

      def apply_raise(self):
        self.pay = int(self.pay * self.raise_amount)

      @classmethod
      def set_raise_amt(cls, amount):
          cls.raise_amt = amount

      @classmethod
      def from_string(cls, emp_str):
          first, last, pay = emp_str_1.split(('-'))
          return cls(first, last, pay)

      @staticmethod
      def is_workday(day):
        if day.weekday() == 5 or day.weekday() == 6:
           return False
        return True

emp_1 = Employee('jan', 'michel', 79000)
emp_2 = Employee('harry', 'cob', 99000)

import datetime
my_date = datetime.date(2016,7,10)

print(Employee.is_workday(my_date))
# Out:
# False

# %% [markdown]
# **4. Inheritance - creating subclasses**

# %%
class Employee:

      raise_amount = 1.04

      def __init__(self, first, last, pay):
          self.first = first
          self.last = last
          self.pay = pay
          self.email = first + '.' + last + '@company.com'

      def fullname(self):
          return ('{} {}'.format(self.first, self.last))

      def apply_raise(self):
        self.pay = int(self.pay * self.raise_amount)

class Developer(Employee):
  raise_amt =1.10

  def __init__(self, first, last, pay, prog_lang):
          super().__init__(first, last, pay)
          self.prog_lang = prog_lang

class manager(Employee):
  def __init__(self, first, last, pay, Employee = None):
          super().__init__(first, last, pay)
          if Employee is None:
            self.Employee = []
          else:
            self.Employee = Employee

  def add_emp(self, emp):
    if emp not in self.Employee:
      self.Employee.append(emp)

  def remove_emp(self, emp):
    if emp in self.employee:
      self.employees.remove(emp)

  def print_emp(self):
    for emp in self.Employee:
      print('-->', emp.fullname())

dev_1 = Developer('jan', 'michel', 79000, 'python')
dev_2 = Developer('harry', 'cob', 99000, 'java')

print(dev_1.email)
print(dev_2.email)

print(dev_1.pay)
dev_1.apply_raise()
print(dev_1.pay)

print(dev_1.prog_lang)

mgr_1 = manager('sun', 'arti', 30000, [dev_1])
print(mgr_1.email)
mgr_1.add_emp(dev_2)
mgr_1.print_emp()
# Out:
# jan.michel@company.com
# harry.cob@company.com
# 79000
# 82160
# python
# sun.arti@company.com
# --> jan michel
# --> harry cob

# %%
class Employee:

      raise_amount = 1.04

      def __init__(self, first, last, pay):
          self.first = first
          self.last = last
          self.pay = pay
          self.email = first + '.' + last + '@company.com'

      def fullname(self):
          return ('{} {}'.format(self.first, self.last))

      def apply_raise(self):
        self.pay = int(self.pay * self.raise_amount)

class Developer(Employee):
  raise_amt =1.10

  def __init__(self, first, last, pay, prog_lang):
          super().__init__(first, last, pay)
          self.prog_lang = prog_lang

class manager(Employee):
  def __init__(self, first, last, pay, Employee = None):
          super().__init__(first, last, pay)
          if Employee is None:
            self.Employee = []
          else:
            self.Employee = Employee

  def add_emp(self, emp):
    if emp not in self.Employee:
      self.Employee.append(emp)

  def remove_emp(self, emp):
    if emp in self.employee:
      self.employees.remove(emp)

  def print_emp(self):
    for emp in self.Employee:
      print('-->', emp.fullname())

dev_1 = Developer('jan', 'michel', 79000, 'python')
dev_2 = Developer('harry', 'cob', 99000, 'java')

mgr_1 = manager('sun', 'arti', 30000, [dev_1])

print(isinstance(mgr_1, manager))
print(isinstance(mgr_1, Employee))
print(isinstance(mgr_1, Developer))

print(issubclass(Developer, Employee))
print(issubclass(manager, Developer))
# Out:
# True
# True
# False
# True
# False

# %% [markdown]
# **5. Special Methods: Magic/Dunder**

# %%
class Employee:

      raise_amount = 1.04

      def __init__(self, first, last, pay):
          self.first = first
          self.last = last
          self.pay = pay
          self.email = first + '.' + last + '@company.com'

      def fullname(self):
          return ('{} {}'.format(self.first, self.last))

      def apply_raise(self):
        self.pay = int(self.pay * Employee.raise_amount)

      def __repr__(self):
        return "Employee('{}','{}',{})".format (self.first, self.last, self.pay)


emp_1 = Employee('jan', 'michel', 79000)
emp_2 = Employee('harry', 'cob', 99000)


print(emp_1)
# Out:
# Employee('jan','michel',79000)

# %%
class Employee:

      raise_amount = 1.04

      def __init__(self, first, last, pay):
          self.first = first
          self.last = last
          self.pay = pay
          self.email = first + '.' + last + '@company.com'

      def fullname(self):
          return ('{} {}'.format(self.first, self.last))

      def apply_raise(self):
        self.pay = int(self.pay * Employee.raise_amount)

      def __str__(self):
        return '{} - {}'.format(self.fullname(), self.email)

      def __add__(self, other):
        return self.pay + other.pay

emp_1 = Employee('jan', 'michel', 79000)
emp_2 = Employee('harry', 'cob', 99000)

print(emp_1 + emp_2)
print(emp_1)
# Out:
# 178000
# jan michel - jan.michel@company.com

# %%
print(1+2)

print(int.__add__(1,2))
print(str.__add__('a','b'))
# Out:
# 3
# 3
# ab

# %% [markdown]
# **6. Property Decorator - Getters, Setters and Deleters**

# %%
class Employee:

    def __init__(self, first, last):
      self.first = first
      self.last = last

    @property
    def email(self):
       return '{}.{}@gmail.com'.format(self.first, self.last)

    @property
    def fullname(self):
       return '{} {}'.format(self.first, self.last)

emp_1 = Employee('John','smith')

emp_1.first = 'Jim'

print(emp_1.first)
print(emp_1.email())
print(emp_1.fullname())
# Out:
# Jim
# Jim.smith@gmail.com
# Jim smith

# %%
class Employee:

    def __init__(self, first, last):
      self.first = first
      self.last = last

    @property
    def email(self):
       return '{}.{}@gmail.com'.format(self.first, self.last)

    @property
    def fullname(self):
       return '{} {}'.format(self.first, self.last)

    @fullname.setter
    def fullname(self,name):
       first, last = name.split(' ')
       self.first=first
       self.last = last

emp_1 = Employee('John','smith')

emp_1.fullname = 'Robin sharma'

print(emp_1.first)
print(emp_1.email)
print(emp_1.fullname)
# Out:
# Robin
# Robin.sharma@gmail.com
# Robin sharma

# %%
class Employee:

    def __init__(self, first, last):
      self.first = first
      self.last = last

    @property
    def email(self):
       return '{}.{}@gmail.com'.format(self.first, self.last)

    @property
    def fullname(self):
       return '{} {}'.format(self.first, self.last)

    @fullname.setter
    def fullname(self,name):
       first, last = name.split(' ')
       self.first=first
       self.last = last

    @fullname.deleter
    def fullname(self):
       print('delete name!')
       self.first = None
       self.last = None

emp_1 = Employee('John','smith')

emp_1.fullname = 'Robin sharma'

print(emp_1.first)
print(emp_1.email)
print(emp_1.fullname)

del emp_1.fullname
# Out:
# Robin
# Robin.sharma@gmail.com
# Robin sharma
# delete name!
